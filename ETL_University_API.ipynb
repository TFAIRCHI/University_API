# %%
"""Import Libs"""
import requests
import json
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

#------- Extract -------
"""Initializing Spark Session"""
spark = SparkSession.builder.appName("test").getOrCreate()
sc = spark.sparkContext
"""Read API That Shows University Information"""
r = requests.request("GET",'http://universities.hipolabs.com/search?country=United+States')
"""Print JSON Fetched file as python dictionary"""
data_j = r.json()

#-------- Transform------
"""Place a list of JSON Objects into a spark dataframe"""
df = sc.parallelize(data_j).map(lambda x: json.dumps(x))
df = spark.read.json(df)
"""The File had a multitude of Null values in the state column which is what I wanted to work with"""
df = df.na.drop(subset=['state-province'])

"""Show Data-Set"""
print('Count of colleges:',df.count())
print(df.columns)
df.select('domains','name','state-province','web_pages').show(truncate=False)

"""Count the number of universities that appeard in the list per state"""
state_sum = df.groupBy("state-province").count()
state_sum.show(50)

"""University Name Contains the name of the state"""
state_univers = df.filter(col("name").contains(col("state-province")))
print('State Name is in College Name:',state_univers.count())
state_univers.select('state-province','name').show(state_univers.count(),truncate=False)
# Out:
# Count of colleges: 83
# ['alpha_two_code', 'country', 'domains', 'name', 'state-province', 'web_pages']
# +------------------------------------------+-------------------------------------------------+--------------+-----------------------------------------+
# |domains                                   |name                                             |state-province|web_pages                                |
# +------------------------------------------+-------------------------------------------------+--------------+-----------------------------------------+
# |[upmc.edu, upmc.com]                      |University of Pittsburgh Medical Center          |Pennsylvania  |[https://www.upmc.com/]                  |
# |[utrgv.edu]                               |The University of Texas at Rio Grande Valley     |Texas         |[https://www.utrgv.edu/]                 |
# |[uvu.edu]                                 |Utah Valley University                           |Utah          |[https://uvu.edu/]                       |
# |[csn.edu]                                 |College of Southern Nevada                       |NV            |[https://www.csn.edu/]                   |
# |[bloomu.edu]                              |Bloomsburg University of Pennsylvania            |Pennsylvania  |[http://www.bloomu.edu/]                 |
# |[cup.edu]                                 |California University of Pennsylvania            |Pennsylvania  |[http://www.cup.edu/]                    |
# |[clarion.edu]                             |Clarion University of Pennsylvania               |Pennsylvania  |[http://www.clarion.edu/]                |
# |[allencollege.edu]                        |Allen College                                    |Iowa          |[https://www.allencollege.edu/]          |
# |[esu.edu]                                 |East Stroudsburg State University of Pennsylvania|Pennsylvania  |[http://www.esu.edu/]                    |
# |[edinboro.edu]                            |Edinboro University of Pennsylvania              |Pennsylvania  |[http://www.edinboro.edu/]               |
# |[ehc.edu]                                 |Emory & Henry College                            |VA            |[https://www.ehc.edu/]                   |
# |[etbu.edu]                                |East Texas Baptist University                    |TX            |[https://www.etbu.edu/]                  |
# |[haverford.edu]                           |Haverford College in Pennsylvania                |Pennsylvania  |[http://www.haverford.edu/]              |
# |[indiana.edu, iub.edu, bloomington.iu.edu]|Indiana University - Bloomington                 |Indiana       |[https://bloomington.iu.edu/]            |
# |[iup.edu]                                 |Indiana University of Pennsylvania               |Pennsylvania  |[http://www.iup.edu/]                    |
# |[kutztown.edu]                            |Kutztown University of Pennsylvania              |Pennsylvania  |[http://www.kutztown.edu/]               |
# |[mansfield.edu]                           |Mansfield University of Pennsylvania             |Pennsylvania  |[http://www.mansfield.edu/]              |
# |[mercyhurst.edu]                          |Mercyhurst University                            |Pennsylvania  |[https://mercyhurst.edu/]                |
# |[denvercollegeofnursing.edu]              |Denver College of Nursing                        |Colorado      |[https://www.denvercollegeofnursing.edu/]|
# |[millersville.edu]                        |Millersville University of Pennsylvania          |Pennsylvania  |[http://www.millersville.edu/]           |
# +------------------------------------------+-------------------------------------------------+--------------+-----------------------------------------+
# only showing top 20 rows
#
# +--------------+-----+
# |state-province|count|
# +--------------+-----+
# |          Utah|    1|
# |         Texas|    4|
# |  Pennsylvania|   31|
# |            NV|    1|
# |            VA|    1|
# |          Iowa|    1|
# |            TX|    2|
# |       Indiana|    1|
# |          Ohio|    2|
# |            IN|    1|
# |      New York|    1|
# |      Colorado|    1|
# |            CA|    2|
# |      Illinois|    1|
# |North Carolina|    2|
# | New Hampshire|    1|
# |South Carolina|    1|
# |    Washington|    2|
# |      Missouri|    1|
# |      Virginia|    1|
# |    California|    5|
# |            NY|    9|
# |            MI|    1|
# |            ND|    1|
# |      Michigan|    1|
# |  New York, NY|    4|
# |            GA|    2|
# |       Florida|    1|
# |         Maine|    1|
# +--------------+-----+
#
# State Name is in College Name: 38
# +--------------+-------------------------------------------------+
# |state-province|name                                             |
# +--------------+-------------------------------------------------+
# |Texas         |The University of Texas at Rio Grande Valley     |
# |Utah          |Utah Valley University                           |
# |Pennsylvania  |Bloomsburg University of Pennsylvania            |
# |Pennsylvania  |California University of Pennsylvania            |
# |Pennsylvania  |Clarion University of Pennsylvania               |
# |Pennsylvania  |East Stroudsburg State University of Pennsylvania|
# |Pennsylvania  |Edinboro University of Pennsylvania              |
# |Pennsylvania  |Haverford College in Pennsylvania                |
# |Indiana       |Indiana University - Bloomington                 |
# |Pennsylvania  |Indiana University of Pennsylvania               |
# |Pennsylvania  |Kutztown University of Pennsylvania              |
# |Pennsylvania  |Mansfield University of Pennsylvania             |
# |Pennsylvania  |Millersville University of Pennsylvania          |
# |Ohio          |Ohio State University - Columbus                 |
# |Pennsylvania  |Pennsylvania College of Technology               |
# |Pennsylvania  |Pennsylvania State University                    |
# |Pennsylvania  |Pennsylvania State University - Schuylkill Campus|
# |Pennsylvania  |Shippensburg University of Pennsylvania          |
# |Pennsylvania  |Slippery Rock University of Pennsylvania         |
# |Illinois      |University of Illinois, Urbana-Champaign         |
# |New Hampshire |University of New Hampshire                      |
# |North Carolina|The University of North Carolina at Greensboro   |
# |Pennsylvania  |University of Pennsylvania                       |
# |Texas         |The University of Texas at Austin                |
# |Texas         |The University of Texas at San Antonio           |
# |Virginia      |Virginia Tech                                    |
# |Pennsylvania  |West Chester University of Pennsylvania          |
# |Pennsylvania  |York College of Pennsylvania                     |
# |NY            |CUNY Baruch College                              |
# |NY            |CUNY Queens College                              |
# |NY            |CUNY City Tech                                   |
# |NY            |CUNY City College of NY                          |
# |NY            |CUNY Brooklyn College                            |
# |NY            |CUNY Medgar Evers College                        |
# |NY            |CUNY College of Staten Island                    |
# |NY            |CUNY Macauly Honors College                      |
# |Pennsylvania  |Pennsylvania Highlands Community College         |
# |Pennsylvania  |Pennsylvania Institute of Technology             |
# +--------------+-------------------------------------------------+

# %%
#------- Load -------
import sqlite3
from sqlite3 import Error

conn = sqlite3.connect('University.db',timeout=10)

cur = conn.cursor()

cur.execute('''CREATE TABLE UNIVERSITY ( 
            STATE VARCHAR(60),
            UNIVERSITY_NAME VARCHAR(60))''')

Key = 1
for row in df.rdd.collect():
    conn.execute("INSERT INTO UNIVERSITY VALUES(?,?)",(row[3],row[4]))
    Key += 1

Cursor = conn.execute("SELECT * FROM UNIVERSITY")
for row in Cursor:
    print(row)

conn.close()
# Out:
# ('University of Pittsburgh Medical Center', 'Pennsylvania')
# ('The University of Texas at Rio Grande Valley', 'Texas')
# ('Utah Valley University', 'Utah')
# ('College of Southern Nevada', 'NV')
# ('Bloomsburg University of Pennsylvania', 'Pennsylvania')
# ('California University of Pennsylvania', 'Pennsylvania')
# ('Clarion University of Pennsylvania', 'Pennsylvania')
# ('Allen College', 'Iowa')
# ('East Stroudsburg State University of Pennsylvania', 'Pennsylvania')
# ('Edinboro University of Pennsylvania', 'Pennsylvania')
# ('Emory & Henry College', 'VA')
# ('East Texas Baptist University', 'TX')
# ('Haverford College in Pennsylvania', 'Pennsylvania')
# ('Indiana University - Bloomington', 'Indiana')
# ('Indiana University of Pennsylvania', 'Pennsylvania')
# ('Kutztown University of Pennsylvania', 'Pennsylvania')
# ('Mansfield University of Pennsylvania', 'Pennsylvania')
# ('Mercyhurst University', 'Pennsylvania')
# ('Denver College of Nursing', 'Colorado')
# ('Millersville University of Pennsylvania', 'Pennsylvania')
# ('Ohio State University - Columbus', 'Ohio')
# ('Pennsylvania College of Technology', 'Pennsylvania')
# ('Pennsylvania State University', 'Pennsylvania')
# ('Pennsylvania State University - Schuylkill Campus', 'Pennsylvania')
# ('Purdue University Fort Wayne', 'IN')
# ('Pittsburg State University', 'Pennsylvania')
# ('St. Francis College', 'New York')
# ('Shippensburg University of Pennsylvania', 'Pennsylvania')
# ('Slippery Rock University of Pennsylvania', 'Pennsylvania')
# ('University of California, Office of the President', 'CA')
# ('UC Hastings College of the Law', 'CA')
# ('University of Illinois, Urbana-Champaign', 'Illinois')
# ('University of New Hampshire', 'New Hampshire')
# ('The University of North Carolina at Greensboro', 'North Carolina')
# ('University of Pennsylvania', 'Pennsylvania')
# ('University of Pittsburgh', 'Pennsylvania')
# ('University of Pittsburgh at Johnstown', 'Pennsylvania')
# ('University of Pittsburgh at Bradford', 'Pennsylvania')
# ('Anderson University', 'South Carolina')
# ('The University of Texas at Austin', 'Texas')
# ('The University of Texas at San Antonio', 'Texas')
# ('Virginia Tech', 'Virginia')
# ('Walla Walla University', 'Washington')
# ('West Chester University of Pennsylvania', 'Pennsylvania')
# ('Westminster College of New Wilmington', 'Pennsylvania')
# ('Westminster College of Fulton', 'Missouri')
# ('York College of Pennsylvania', 'Pennsylvania')
# ('Houston Baptist University', 'TX')
# ('San Bernardino Valley College', 'California')
# ('San Diego City College', 'California')
# ('San Diego Mesa College', 'California')
# ('San Diego Miramar College', 'California')
# ('CUNY Baruch College', 'NY')
# ('CUNY Queens College', 'NY')
# ('CUNY City Tech', 'NY')
# ('CUNY City College of NY', 'NY')
# ('CUNY Brooklyn College', 'NY')
# ('CUNY Medgar Evers College', 'NY')
# ('CUNY College of Staten Island', 'NY')
# ('CUNY Macauly Honors College', 'NY')
# ('Pennsylvania Highlands Community College', 'Pennsylvania')
# ('Pennsylvania Institute of Technology', 'Pennsylvania')
# ('Pittsburgh Technical Institute', 'Pennsylvania')
# ('University of Pittsburgh-\u200bTitusville', 'Pennsylvania')
# ('Schreiner University', 'Texas')
# ('Trinity Bible College & Graduate School', 'ND')
# ('University of Michigan-Flint', 'MI')
# ('Defiance College', 'Ohio')
# ('Gulf Coast State College', 'Florida')
# ('Academy of Art University', 'California')
# ('Lenoir-Rhyne University', 'North Carolina')
# ('Point Park University', 'Pennsylvania')
# ('Northwood University', 'Michigan')
# ('Clark Atlanta University', 'GA')
# ('Morehouse', 'GA')
# ('Gwynedd Mercy University', 'Pennsylvania')
# ('Bellevue College', 'Washington')
# ('CUNY Lehman College', 'New York, NY')
# ('CUNY John Jay College of Criminal Justice', 'New York, NY')
# ('Hunter College CUNY', 'New York, NY')
# ('CUNY York College', 'New York, NY')
# ('Unity Environmental College', 'Maine')
# ('Island Drafting & Technical Institute', 'NY')

# %%
df
# Out:
# DataFrame[alpha_two_code: string, country: string, domains: array<string>, name: string, state-province: string, web_pages: array<string>]

# %%
df.show()
# Out:
# +--------------+-------------+--------------------+--------------------+--------------+--------------------+
# |alpha_two_code|      country|             domains|                name|state-province|           web_pages|
# +--------------+-------------+--------------------+--------------------+--------------+--------------------+
# |            US|United States|[upmc.edu, upmc.com]|University of Pit...|  Pennsylvania|[https://www.upmc...|
# |            US|United States|         [utrgv.edu]|The University of...|         Texas|[https://www.utrg...|
# |            US|United States|           [uvu.edu]|Utah Valley Unive...|          Utah|  [https://uvu.edu/]|
# |            US|United States|           [csn.edu]|College of Southe...|            NV|[https://www.csn....|
# |            US|United States|        [bloomu.edu]|Bloomsburg Univer...|  Pennsylvania|[http://www.bloom...|
# |            US|United States|           [cup.edu]|California Univer...|  Pennsylvania|[http://www.cup.e...|
# |            US|United States|       [clarion.edu]|Clarion Universit...|  Pennsylvania|[http://www.clari...|
# |            US|United States|  [allencollege.edu]|       Allen College|          Iowa|[https://www.alle...|
# |            US|United States|           [esu.edu]|East Stroudsburg ...|  Pennsylvania|[http://www.esu.e...|
# |            US|United States|      [edinboro.edu]|Edinboro Universi...|  Pennsylvania|[http://www.edinb...|
# |            US|United States|           [ehc.edu]|Emory & Henry Col...|            VA|[https://www.ehc....|
# |            US|United States|          [etbu.edu]|East Texas Baptis...|            TX|[https://www.etbu...|
# |            US|United States|     [haverford.edu]|Haverford College...|  Pennsylvania|[http://www.haver...|
# |            US|United States|[indiana.edu, iub...|Indiana Universit...|       Indiana|[https://blooming...|
# |            US|United States|           [iup.edu]|Indiana Universit...|  Pennsylvania|[http://www.iup.e...|
# |            US|United States|      [kutztown.edu]|Kutztown Universi...|  Pennsylvania|[http://www.kutzt...|
# |            US|United States|     [mansfield.edu]|Mansfield Univers...|  Pennsylvania|[http://www.mansf...|
# |            US|United States|    [mercyhurst.edu]|Mercyhurst Univer...|  Pennsylvania|[https://mercyhur...|
# |            US|United States|[denvercollegeofn...|Denver College of...|      Colorado|[https://www.denv...|
# |            US|United States|  [millersville.edu]|Millersville Univ...|  Pennsylvania|[http://www.mille...|
# +--------------+-------------+--------------------+--------------------+--------------+--------------------+
# only showing top 20 rows
